# %%
import torch 
from torch import nn

# %%
relu = nn.ReLU()

# %%
maxpool = nn.MaxPool2d(
    kernel_size = 3,
    stride = 2,
)

# %%
conv1 = nn.Conv2d(
    in_channels = 3,
    out_channels = 96,
    kernel_size = 11,
    stride = 4,
)

# %%
conv2 = nn.Conv2d(
    in_channels = 96,
    out_channels = 256,
    kernel_size = 5,
    stride=1,
    padding=2,
)

# %%
conv3 = nn.Conv2d(256, 384, kernel_size=3, padding=1)

# %%
conv4 = nn.Conv2d(25)
